# %% [markdown]
# # <span style="color:red"> Targeted-from-mzTab notebook for IODA </span>
#
# **Purpose**: The IODA targeted-from-mzTab workflow takes allows to generate list of target ions for iterative optimise data acquisition (IODA) of fragmentation spectra in LC-MS. It accepts as input an mzTab file with results for two samples: the "reference" sample and the "blank" sample. The targets are detected in the "reference" sample, and background ions are detected in the "blank" sample. Background ions are excluded from the targets. The targets can be acquired by IODA in one or multiple experiments for higher coverage.
#
#
# **Usage**: This notebook requires the user to provide an mzTab. If you need to process your LC-MS data, you can use our [IODA targeted-from-mzML notebook](IODA_targeted_from_mzML.ipynb), or refer to our documentation for more informations. The IODA targeted workflow defines the target ions, and these targets are then formatted for XCalibur or [MaxQuant.Live](http://www.maxquant.live/).
#
# **Documentation**: Please refer to the documentation page [See here](link).
#
# **Instructions**: Follow the instructions below and run the notebook cells accordingly.

# %% [markdown]
# ### Step 0 - Generate an mzTab file
#
# The mzTab file must contain results from feature detection and alignment for the two samples: the "reference" sample and the "blank' sample. Please refer to the [documentation page](link) for more information.
#
# ### Step 1 - Upload the mzTab file
#
# ##### <span style="color:brown">Method 1 - Upload your mzTab file </span>
#
# Upload your mzML files on the Binder server with the Jupyter lab interface (drag-and-drop the file in the left panel or use the "Upload" icon).
#
# ##### <span style="color:brown">Method 2 - Web-sharing links</span>
# We support retrieving the files from the following cloud sharing services:
# > **Google Drive** : copy the sharing the link (make sure the sharing setting is set to 'Anyone with the link can download').
#
# > **MassIVE/GNPS repository** : copy the link for the file.
#
#
# ### Step 3 - Specify the link or path to the mzTab file
#
# In the cell below, indicate the filename for the mzTab file. The filename must be into parenthesis,  such as:\
# `input_mzTab = "myfile.mzTab"` or `input_mzTab = "input_folder/myfile.mzTab"`
#
# *This test files could be used*:\
# `input_mzTab = "tests/Euphorbia/Targeted/toppas_output/Targeted_MZtab/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.mzTab"`
# -
# <!--This is an other test jobs
# input_mzTab = 'https://drive.google.com/file/d/1NGVzhrw-xZ4nMJserIQ7v4tYgcmraZ6g/view?usp=sharing'
# -->

# %%
input_mzTab = "myfile.mzTab"
input_mzTab = "tests/Euphorbia/Targeted/toppas_output/Targeted_MZtab/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.mzTab"

# %% [markdown]
# ### Step 4 - Specify the parameters of the IODA-targeted workflow
# **Specify the parameter values for IODA-targeted workflow in the cell below:**
#
# **Description**: At this step, we will generate target ions with the IODA-targeted workflow.
#
# The target ions are ions from the reference sample that are meeting some user-defined parameters. Valid target ions are those 1) that have an intensity above the minimum intensity defined and 2) that have an intensity ratio between the reference/blank samples above the defined value. The target ions can be splitted accross multiple iterative experiments. Retention time range above the peak apex for the target ions are also defined by the user.
#
# >`min_intensity_value`: the minimum intensity (peak height) of an ion/feature in the reference sample to be considered as valid ion targets. Default = 3E5.
#
# >`min_ratio_value`: minimum ratio for the intensity of an ion/feature (peak height) between the reference and blank samples (reference/blank). Only ions above that ratio will be valid ion targets. Default = 3.
#
# >`experiment_number`: define the number of iterative experiment(s) to perform for the IODA-targeted workflow. If >2, the valid target ions will be splitted into multiple experiments. Default = 3, range 1-10.
#
# >`pretarget_rt_margin`: Retention time margin before the target ion apex (in seconds). Default = 0.5.
#
# >`posttarget_rt_margin`: Retention time margin after the target ion apex (in seconds). By default it is more than the `pretarget_rt_margin` due to the frequent non-gaussian nature of LC-MS features. Note that this value could be increased to reach the dynamic exclusion time parameter of the acquisition method. Default = 5.
#
# >`min_int_apex_ratio`: Used only for Exploris. Minimum ion intensity specified in the inclusion list (absolute count. Default = 5E4
#
# >`window_bin`:Windows  (in seconds). By default it is more than the `pretarget_rt_margin` due to the frequent non-gaussian nature of LC-MS features. Note that this value could be increased to reach the dynamic exclusion time parameter of the acquisition method. Default = 5.

# %%
min_intensity_value = 3E5
min_ratio_value = 3
experiment_number = 5
pretarget_rt_margin = 1
posttarget_rt_margin = 5
posttarget_rt_margin = 5
min_int_apex_ratio = 5E4
window_bin = 30

# %% [markdown]
# ### Step 5 - Run the IODA-targeted workflow
#
# Simply run the cell below to start the IODA-targeted workflow

# %%
from IODA_targeted_workflow import *
make_targeted_list_from_feature_table_or_mztab(input_mzTab, experiment_number, min_ratio_value, min_intensity_value,\
                              pretarget_rt_margin,posttarget_rt_margin, 30, min_int_apex_ratio )
# Out:
# mkdir: cannot create directory ‘download_results’: File exists
# rm: cannot remove 'results/logfile.txt': No such file or directory
# [I 230316 13:57:08 IODA_targeted_workflow2:271] STARTING THE IODA targeted-from-FeatureTable WORKFLOW
# [I 230316 13:57:08 IODA_targeted_workflow2:278] An mzTab was provided
# /home/jovyan/IODA_targeted_workflow2.py:280: FutureWarning: The warn_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   convert_mzTab_to_table(input_filepath, consensus_df_path)
# /home/jovyan/IODA_targeted_workflow2.py:280: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   convert_mzTab_to_table(input_filepath, consensus_df_path)
# [I 230316 13:57:08 IODA_targeted_workflow2:73] - For sample Euphorbia_rogers_latex_Blank_MS1_2uL the sum of feature intensities is = 6.67e+08
# [I 230316 13:57:08 IODA_targeted_workflow2:75] - For sample Euphorbia_rogers_latex_latex_MS1_2uL the sum of feature intensities = 5.75e+10
# [I 230316 13:57:08 IODA_targeted_workflow2:281] This is the output file path of the converted mzTab: OpenMS_workflow/OpenMS_output/consensus.csv
# [I 230316 13:57:08 IODA_targeted_workflow2:289] 2023-03-16 13:57:08.599714
# [I 230316 13:57:08 IODA_targeted_workflow2:292] ======
# [I 230316 13:57:08 IODA_targeted_workflow2:293] Getting the input file
# [I 230316 13:57:08 IODA_targeted_workflow2:294] ======
# [I 230316 13:57:08 IODA_targeted_workflow2:299] Assumed reference sample filename: Euphorbia_rogers_latex_latex_MS1_2uL
# [I 230316 13:57:08 IODA_targeted_workflow2:301] Assumed blank filename: Euphorbia_rogers_latex_Blank_MS1_2uL
# [I 230316 13:57:08 IODA_targeted_workflow2:302] ======
# [I 230316 13:57:08 IODA_targeted_workflow2:305] User-defined parameters
# [I 230316 13:57:08 IODA_targeted_workflow2:306]    Ratio between sample/blank intensity for valid target ions = 3
# [I 230316 13:57:08 IODA_targeted_workflow2:307]    Minimum intensity for ion filtering in the reference sample = 300000.0
# [I 230316 13:57:08 IODA_targeted_workflow2:308]    Number of iterative experiment(s) for target ions = 5
# [I 230316 13:57:08 IODA_targeted_workflow2:309] ======
# [I 230316 13:57:08 IODA_targeted_workflow2:312] Retention time range parameters:
# [I 230316 13:57:08 IODA_targeted_workflow2:314]    Excluded ion retention time (sec.) = 6
# [I 230316 13:57:08 IODA_targeted_workflow2:315]    Pre-target ion retention time margin (sec.) = 1
# [I 230316 13:57:08 IODA_targeted_workflow2:316]    Post-target ion retention time margin (sec.) = 5
# [I 230316 13:57:08 IODA_targeted_workflow2:317]    Minimum intensity apex ratio (only Exploris serie) = 3
# [I 230316 13:57:08 IODA_targeted_workflow2:320] ======
# [I 230316 13:57:08 IODA_targeted_workflow2:321] Splitting parameters
# [I 230316 13:57:08 IODA_targeted_workflow2:322]    Retention time window (sec.) for binning target ions = 30
# [I 230316 13:57:08 IODA_targeted_workflow2:324] ======
# [I 230316 13:57:08 IODA_targeted_workflow2:327] Processing the ions ...
# [I 230316 13:57:08 IODA_targeted_workflow2:328] ======
# [I 230316 13:57:08 IODA_targeted_workflow2:106] EXCLUSION
# [I 230316 13:57:08 IODA_targeted_workflow2:107]    Number of ions in the blank sample = 436, with int. != 0
# [I 230316 13:57:08 IODA_targeted_workflow2:115]    Number of ions shared between blank and reference samples = 303, with int. != 0
# [I 230316 13:57:08 IODA_targeted_workflow2:331] ======
# [I 230316 13:57:08 IODA_targeted_workflow2:125] TARGETED METHOD
# [I 230316 13:57:08 IODA_targeted_workflow2:126]    Number of ions in the reference sample = 5894
# [I 230316 13:57:08 IODA_targeted_workflow2:127]    Number of target ions with minimum intensity (300000.0) = 5793
# [I 230316 13:57:08 IODA_targeted_workflow2:128]    Number of target ions with reference sample/blank ratio > 3, n = 5609
# [I 230316 13:57:08 IODA_targeted_workflow2:129]    Number of target ions with both minimum intensity and ratio filters = 5529
# [I 230316 13:57:08 IODA_targeted_workflow2:333] ======
# [I 230316 13:57:08 IODA_targeted_workflow2:336] Splitting the target ions per intensity in a given retention time bin
# [I 230316 13:57:08 IODA_targeted_workflow2:340]    Number of target ions per experiment n = 1112
# [I 230316 13:57:08 IODA_targeted_workflow2:341] ======
# [I 230316 13:57:08 IODA_targeted_workflow2:350] Plotting the ions ... please wait ...
# [I 230316 13:57:14 IODA_targeted_workflow2:359] ======
# [I 230316 13:57:14 IODA_targeted_workflow2:362] Converting tables to XCalibur format (Exactive serie) ...
# [I 230316 13:57:14 IODA_targeted_workflow2:367] ======
# [I 230316 13:57:14 IODA_targeted_workflow2:370] Converting tables to XCalibur format (Exploris serie) ...
# [I 230316 13:57:14 IODA_targeted_workflow2:376] ======
# [I 230316 13:57:14 IODA_targeted_workflow2:380] Converting tables to MaxQuant.Live format ...
# [I 230316 13:57:15 IODA_targeted_workflow2:386] ======
# [I 230316 13:57:15 IODA_targeted_workflow2:387] Cleaning and zipping workflow results files ...
# mv: cannot stat 'OpenMS_workflow/OpenMS_output/*blank.csv': No such file or directory
# mv: cannot stat 'OpenMS_workflow/logfile_IODA_OpenMS_from_mzML.txt': No such file or directory
# [I 230316 13:57:15 IODA_targeted_workflow2:260] All files zipped successfully!
# [I 230316 13:57:15 IODA_targeted_workflow2:459] ======
# [I 230316 13:57:15 IODA_targeted_workflow2:460] END OF THE IODA-targeted-from-mzML WORKFLOW
# [I 230316 13:57:15 IODA_targeted_workflow2:461] ======

# %% [markdown]
# ### Step 6 - Examine the results
#
# **Examinate the log above**: Evaluate if the parameters are adapted to your sample(s) complexity and experimental set-up. In particular:
#    > - Evaluate the parameters for the target ions selection methods (shotgun, intensity and ratio): look for how many ions were filtered out. If needed adjust the parameter value(s) for `min_ratio_value`, `min_intensity_value`.
#    > - Limit the maximum number of target ions for a single experiment to 1000-2000 to your experimental conditions and sample complexity. This is multi-factorial (chromatographic method, performance of MS instrument, MS method, and sample complexity). You can filter out target ions with by increasing the parameters `min_ratio_value`, `min_intensity_value`. Or you can modulate the number iterative experiments with the parameters: `experiment_number`.
#
#    > NB: at this stage, it cannot be evaluated if ion detection was done optimally. This should be examinated during the generation of the mzTab file (such as with TOPPAS/OpenMS).
#
# **Visualise** : Run the cell below to show the scatter plot for the IODA-targeted workflow results. Valid target ions in the reference sample are represented into experiment(s). The ion/features from the blank sample are also shown.

# %%
from IPython.display import Image
import glob
filename = glob.glob('results_targeted/plots/*_blank_shared_MZ_RT_TARGETED_scatter_plot.png')
Image(filename[0])

# %%
filename = glob.glob('results_targeted/plots/*_shared_MZ_TARGETED_scatter_plot.png')
Image(filename[0])

# %%
filename = glob.glob('results_targeted/plots/*_shared_MZ_TARGETED_scatter_plot.png')
Image(filename[0])

# %%
filename = glob.glob('results_targeted/plots/*_blank_shared_MZ_RT_TARGETED_scatter_plot.png')
Image(filename[0])

# %% [markdown]
# ### Step 7 - Download the results
#
# Run the cell below to display the download links for the:
# - **IODA-targeted workflow results** -> `download_results/IODA_targeted_results.zip`

# %%
from download_link_jupyterlab import DownloadFileLink
display(DownloadFileLink('download_results/IODA_targeted_results.zip', file_name='download_results/IODA_targeted_results.zip', link_text='Download the IODA targeted workflow results from download_results/IODA_targeted_results.zip'))
# Out:
# /home/jovyan/download_results/IODA_targeted_results.zip

# %% [markdown]
# ### Step 8 - Prepare your IODA experiment
# Prepare the iterative mass spectrometry acquisition. For instructions on how to load and configure an exclusion list with XCalibur or MaxQuant.Live please refer to [the following documentation](nothing).
