# %% [markdown]
# # <span style="color:red"> MS2Planner-from-mzML notebook </span>
#
# **Purpose**: Run PathFinder in all modes
#
#
# **Usage**: Select the data and run the cells

# %% [markdown]
# # SELECT WHICH DATA YOU WANNA TRY

# %% [markdown]
# ## 1) Euphorbia data

# %%
# Blank sample
input_BLANK = "tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_Blank_MS1_2uL.mzML"
# Reference sample
input_SAMPLE = "tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_latex_MS1_2uL.mzML"

#input_BLANK = 'Euphorbia_Blank_MS1_5uL.mzML'
#input_SAMPLE = 'Euphorbia_MS1_5uL.mzML'

# %% [markdown]
# ## 2) SA113 Test data

# %%
# Blank sample
input_BLANK = "tests/BP_mzTab/SA113_SPE_MeOH_MS1.mzML"
# Reference sample
input_SAMPLE = "tests/BP_mzTab/SA113_Media_SPE_MeOH_MS1.mzML"

# %% [markdown]
# ## 3) Disolved Organic Matter via Google Drive

# %%
input_BLANK = "https://drive.google.com/file/d/10A1XZhcKCVXIKf4v7aLX0tNYM011qV_Z/view?usp=sharing"
# Reference sample
input_SAMPLE = "https://drive.google.com/file/d/1CoKzvreEgT0mq4JEBuB-2T0VFfoHFhZT/view?usp=sharing"

# %%
# OpenMS FeatureFinderMetabolomics parameters
ppm_error = 10
noise_level = 3E5

# %%
from IODA_run_OpenMS_targeted import *
IODA_targeted_workflow(input_BLANK,input_SAMPLE,ppm_error,noise_level)
# Out:
# [I 210804 12:39:34 IODA_run_OpenMS_targeted:40] 2021-08-04 12:39:34.985885
# [I 210804 12:39:34 IODA_run_OpenMS_targeted:41] STARTING the IODA-targeted WORKFLOW
# [I 210804 12:39:34 IODA_run_OpenMS_targeted:42] ======
# [I 210804 12:39:34 IODA_run_OpenMS_targeted:43] Path to the input files:
# [I 210804 12:39:34 IODA_run_OpenMS_targeted:44] Blank: tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_Blank_MS1_2uL.mzML
# [I 210804 12:39:34 IODA_run_OpenMS_targeted:45] Sample: tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_latex_MS1_2uL.mzML
# [I 210804 12:39:34 IODA_run_OpenMS_targeted:96] Copying the mzML files ...
# [I 210804 12:39:34 IODA_run_OpenMS_targeted:83] Path to uploaded file: tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_Blank_MS1_2uL.mzML
# [I 210804 12:39:35 IODA_run_OpenMS_targeted:93] The mzML file was found
# [I 210804 12:39:35 IODA_run_OpenMS_targeted:83] Path to uploaded file: tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_latex_MS1_2uL.mzML
# [I 210804 12:39:35 IODA_run_OpenMS_targeted:93] The mzML file was found
# [I 210804 12:39:35 IODA_run_OpenMS_targeted:100] ======
# [I 210804 12:39:35 IODA_run_OpenMS_targeted:101] Changing the variables of the OpenMS workflow ...
# [I 210804 12:39:35 IODA_run_OpenMS_targeted:102]    ppm error = 10
# [I 210804 12:39:35 IODA_run_OpenMS_targeted:103]    noise threshold = 3.00e+05
# [I 210804 12:39:35 IODA_run_OpenMS_targeted:145] ======
# [I 210804 12:39:35 IODA_run_OpenMS_targeted:146] Initializing the OpenMS workflow
# [I 210804 12:39:35 IODA_run_OpenMS_targeted:154] ======
# [I 210804 12:39:35 IODA_run_OpenMS_targeted:155] Running the OpenMS workflow, this usually takes less than a minute, please wait ...
# [I 210804 12:39:35 IODA_run_OpenMS_targeted:156] If this takes longer, increase the noise treshold value ...
# [I 210804 12:39:53 IODA_run_OpenMS_targeted:182] ======
# [I 210804 12:39:53 IODA_run_OpenMS_targeted:183] Completed the OpenMS workflow
# [I 210804 12:39:53 IODA_run_OpenMS_targeted:184] ======
# [I 210804 12:39:53 IODA_run_OpenMS_targeted:185] Zipping up the OpenMS workflow results ..
# [I 210804 12:39:54 IODA_exclusion_workflow:156] All files zipped successfully!
# [I 210804 12:39:54 IODA_run_OpenMS_targeted:188] ======
# [I 210804 12:39:54 IODA_run_OpenMS_targeted:189] Completed zipping up the OpenMS workflow result files
# [I 210804 12:39:54 IODA_run_OpenMS_targeted:191] ======
# [I 210804 12:39:54 IODA_run_OpenMS_targeted:192] NOW CONTINUE WITH THE REST OF THE IODA-targeted WORKFLOW

# %% [markdown]
# ## Run MS2Planner

# %%
from IODA_MS2Planner_workflow import *

# %% [markdown]
# ### Shared parameters for the modes (baseline/apex/curve)

# %%
# Best Path shared parameters
min_ratio_value = 3
min_intensity_value = 0#1E4
experiment_number = 3
isolation = 1.5
delay = 0.02 #sec

# Target ion list parameters
rt_margin = 1 #sec

# %% [markdown]
# ### MS2Planner in Baseline mode

# %%
# Baseline parameter
win_len = 0.15 #sec (duration of scan)

# %%
# Run Path Finder with Baseline method 
run_MS2Planner_baseline_from_mzTab('OpenMS_generated', experiment_number, min_ratio_value,\
                                   min_intensity_value, win_len, isolation, delay, \
                                   rt_margin)
# Out:
# [I 210804 12:39:54 IODA_MS2Planner_workflow:131] STARTING THE MS2Planner WORKFLOW
# [I 210804 12:39:54 IODA_MS2Planner_workflow:136] The mzTab was generated with the IODA-OpenMS workflow
# [I 210804 12:39:54 IODA_MS2Planner_workflow:145] 2021-08-04 12:39:54.166035
# [I 210804 12:39:54 IODA_MS2Planner_workflow:147] ======
# [I 210804 12:39:54 IODA_MS2Planner_workflow:148] Getting the mzTab
# [I 210804 12:39:54 IODA_MS2Planner_workflow:164] This is the input file path: TOPPAS_Workflow/toppas_output/TOPPAS_out/Targeted_MzTab/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.mzTab
# [I 210804 12:39:54 IODA_MS2Planner_workflow:165] This is the output file path: results_targeted_MS2Planner_baseline/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.csv
# [I 210804 12:39:54 IODA_MS2Planner_workflow:169] ======
# [I 210804 12:39:54 IODA_MS2Planner_workflow:170] Converting mzTab to intermediate table format ...
# [I 210804 12:39:54 IODA_MS2Planner_workflow:76] - For sample Euphorbia_rogers_latex_Blank_MS1_2uL the sum of feature intensities is = 5.30e+08
# [I 210804 12:39:54 IODA_MS2Planner_workflow:78] - For sample Euphorbia_rogers_latex_latex_MS1_2uL the sum of feature intensities = 3.81e+10
# [I 210804 12:39:54 IODA_MS2Planner_workflow:172] ======
# [I 210804 12:39:54 IODA_MS2Planner_workflow:177] Assumed sample filename: Euphorbia_rogers_latex_latex_MS1_2uL
# [I 210804 12:39:54 IODA_MS2Planner_workflow:179] Assumed blank filename: Euphorbia_rogers_latex_Blank_MS1_2uL
# [I 210804 12:39:54 IODA_MS2Planner_workflow:180] ======
# [I 210804 12:39:54 IODA_MS2Planner_workflow:183] User-defined parameters
# [I 210804 12:39:54 IODA_MS2Planner_workflow:185]     Ratio between sample/blank for ion filtering = 3
# [I 210804 12:39:54 IODA_MS2Planner_workflow:187]     Minimum intensity for ion filtering in sample = 0.00e+00
# [I 210804 12:39:54 IODA_MS2Planner_workflow:188]     Retention time window (min.) for binning target ions = 0.15
# [I 210804 12:39:54 IODA_MS2Planner_workflow:189]     Isolation window (m/z) = 1.5
# [I 210804 12:39:54 IODA_MS2Planner_workflow:190]     Retention time margin (sec.) = 0.02
# [I 210804 12:39:54 IODA_MS2Planner_workflow:192]     Number of iterative experiment(s) = 3
# [I 210804 12:39:54 IODA_MS2Planner_workflow:193] User-defined parameters for the output
# [I 210804 12:39:54 IODA_MS2Planner_workflow:194]     Retention time margin for target ion list (sec. = 1
# [I 210804 12:39:54 IODA_MS2Planner_workflow:195] ======
# [I 210804 12:39:54 IODA_MS2Planner_workflow:198] Running MS2Planner in Baseline mode ...
# [I 210804 12:39:54 IODA_MS2Planner_workflow:689] Command: python3 MS2Planner/path_finder.py baseline results_targeted_MS2Planner_baseline/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.csv results_targeted_MS2Planner_baseline/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd_MS2Planner.csv 0 3 3 -win_len 0.15 -isolation 1.5 -delay 0.02
# TOPPAS_Workflow/toppas_output/TOPPAS_out/Targeted_MzTab/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.mzTab
# [I 210804 12:39:55 IODA_MS2Planner_workflow:214] ======
# [I 210804 12:39:55 IODA_MS2Planner_workflow:218] 2021-08-04 12:39:55,568 - path_finder - INFO - =============
#     2021-08-04 12:39:55,568 - path_finder - INFO - Baseline mode begin
#     2021-08-04 12:39:55,568 - path_finder - INFO - =============
#     2021-08-04 12:39:55,568 - path_finder - INFO - File Read
#     2021-08-04 12:39:55,568 - path_finder - INFO - =============
#     2021-08-04 12:39:55,569 - path_finder - INFO - Begin Finding Path
#     2021-08-04 12:39:55,569 - path_finder - INFO - =============
#     2021-08-04 12:39:55,618 - path_finder.baseline - INFO - [1/3]: features: 902, rest: 1832
#     2021-08-04 12:39:55,618 - path_finder.baseline - INFO - [2/3]: features: 482, rest: 1350
#     2021-08-04 12:39:55,618 - path_finder.baseline - INFO - [3/3]: features: 313, rest: 1037
#     2021-08-04 12:39:55,618 - path_finder - INFO - Paths Generated
#     2021-08-04 12:39:55,618 - path_finder - INFO - =============
#     2021-08-04 12:39:55,629 - path_finder - INFO - File Written
#     2021-08-04 12:39:55,629 - path_finder - INFO - =============
#
# [I 210804 12:39:55 IODA_MS2Planner_workflow:223] MS2Planner Path output found
# [I 210804 12:39:55 IODA_MS2Planner_workflow:232] Preparing results ...
# [I 210804 12:39:55 IODA_MS2Planner_workflow:651] File processed: results_targeted_MS2Planner_baseline/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd_MS2Planner.csv
# [I 210804 12:39:55 IODA_MS2Planner_workflow:652] ======
# [I 210804 12:39:56 IODA_MS2Planner_workflow:644] Valid target ions in path1 = 902
# [I 210804 12:39:56 IODA_MS2Planner_workflow:661] Formatting to XCalibur format ...
# [I 210804 12:39:56 IODA_MS2Planner_workflow:664] Formatting for MaxQuant.Live ...
# [I 210804 12:39:56 IODA_MS2Planner_workflow:667] =======
# [I 210804 12:39:56 IODA_MS2Planner_workflow:644] Valid target ions in path2 = 482
# [I 210804 12:39:56 IODA_MS2Planner_workflow:661] Formatting to XCalibur format ...
# [I 210804 12:39:56 IODA_MS2Planner_workflow:664] Formatting for MaxQuant.Live ...
# [I 210804 12:39:56 IODA_MS2Planner_workflow:667] =======
# [I 210804 12:39:56 IODA_MS2Planner_workflow:644] Valid target ions in path3 = 313
# [I 210804 12:39:56 IODA_MS2Planner_workflow:661] Formatting to XCalibur format ...
# [I 210804 12:39:56 IODA_MS2Planner_workflow:664] Formatting for MaxQuant.Live ...
# [I 210804 12:39:56 IODA_MS2Planner_workflow:667] =======
# [I 210804 12:39:56 IODA_MS2Planner_workflow:676] results_targeted_MS2Planner_baseline
# [I 210804 12:40:01 IODA_MS2Planner_workflow:235] ======
# [I 210804 12:40:01 IODA_MS2Planner_workflow:237] Cleaning and zipping workflow results files ...
# [I 210804 12:40:01 IODA_MS2Planner_workflow:119] All files zipped successfully!
# [I 210804 12:40:01 IODA_MS2Planner_workflow:266] ======
# [I 210804 12:40:01 IODA_MS2Planner_workflow:267] END OF THE MS2Planner WORKFLOW
# [I 210804 12:40:01 IODA_MS2Planner_workflow:268] ======

# %%
# !python3 path_finder.py baseline results_targeted_MS2Planner_baseline/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.csv results_targeted_MS2Planner_baseline/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd_MS2Planner.csv 0 3 3 -win_len 0.15 -isolation 1.5 -delay 0.02
# Out:
# python3: can't open file 'path_finder.py': [Errno 2] No such file or directory

# %%
# !pip3 install pymzml
# Out:
# Collecting pymzml
#   Downloading https://files.pythonhosted.org/packages/9b/8e/e84df030daafcbcf2ee8509f1e4ab098ce60659a9cfea6f3bf1eb4595ca4/pymzml-2.4.7-py3-none-any.whl (17.3MB)
#     100% |################################| 17.3MB 62kB/s  eta 0:00:01
# Collecting regex (from pymzml)
#   Downloading https://files.pythonhosted.org/packages/06/0c/38f156bc6b852574ab357d1b13c400e7f09efb0bc9e72379046b10b72217/regex-2021.8.3-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (665kB)
#     100% |################################| 665kB 1.7MB/s eta 0:00:01
# Collecting numpy>=1.8.0 (from pymzml)
#   Downloading https://files.pythonhosted.org/packages/45/b2/6c7545bb7a38754d63048c7696804a0d947328125d81bf12beaa692c3ae3/numpy-1.19.5-cp36-cp36m-manylinux1_x86_64.whl (13.4MB)
#     100% |################################| 13.4MB 83kB/s  eta 0:00:01
# Installing collected packages: regex, numpy, pymzml
# Successfully installed numpy-1.19.5 pymzml-2.4.7 regex-2021.8.3

# %%
from IPython.display import Image
Image("results_targeted_MS2Planner_baseline/plots/injection_scatter_plot_intensity_rt.png")

# %%
Image("results_targeted_MS2Planner_baseline/plots/injection_scatter_plot_mz_rt.png")

# %%
Image("results_targeted_MS2Planner_baseline/plots/scatter_plot_duration.png")

# %% [markdown]
# ### MS2Planner in Apex mode

# %%
# Apex parameters
intensity_accu = 4e4
min_scan = 0.1
max_scan = 0.5

rt_margin = 1
transient_time = 80 #msec

# %%
# Run Path Finder with Apex method
run_MS2Planner_apex_from_mzTab('OpenMS_generated', experiment_number, min_ratio_value, min_intensity_value, intensity_accu, isolation, delay, min_scan, max_scan, rt_margin, transient_time)
# Out:
# [I 210804 12:40:11 IODA_MS2Planner_workflow:283] STARTING THE MS2Planner WORKFLOW
# [I 210804 12:40:11 IODA_MS2Planner_workflow:288] The mzTab was generated with the IODA-OpenMS workflow
# [I 210804 12:40:11 IODA_MS2Planner_workflow:296] 2021-08-04 12:40:11.835660
# [I 210804 12:40:11 IODA_MS2Planner_workflow:298] ======
# [I 210804 12:40:11 IODA_MS2Planner_workflow:299] Getting the mzTab
# [I 210804 12:40:11 IODA_MS2Planner_workflow:315] This is the input file path: TOPPAS_Workflow/toppas_output/TOPPAS_out/Targeted_MzTab/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.mzTab
# [I 210804 12:40:11 IODA_MS2Planner_workflow:316] This is the output file path: results_targeted_MS2Planner_apex/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.csv
# [I 210804 12:40:11 IODA_MS2Planner_workflow:320] ======
# [I 210804 12:40:11 IODA_MS2Planner_workflow:321] Converting mzTab to intermediate table format ...
# [I 210804 12:40:11 IODA_MS2Planner_workflow:76] - For sample Euphorbia_rogers_latex_Blank_MS1_2uL the sum of feature intensities is = 5.30e+08
# [I 210804 12:40:11 IODA_MS2Planner_workflow:78] - For sample Euphorbia_rogers_latex_latex_MS1_2uL the sum of feature intensities = 3.81e+10
# [I 210804 12:40:11 IODA_MS2Planner_workflow:323] ======
# [I 210804 12:40:11 IODA_MS2Planner_workflow:328] Assumed sample filename: Euphorbia_rogers_latex_latex_MS1_2uL
# [I 210804 12:40:11 IODA_MS2Planner_workflow:330] Assumed blank filename: Euphorbia_rogers_latex_Blank_MS1_2uL
# [I 210804 12:40:11 IODA_MS2Planner_workflow:331] ======
# [I 210804 12:40:11 IODA_MS2Planner_workflow:334] User-defined parameters
# [I 210804 12:40:11 IODA_MS2Planner_workflow:336]     Ratio between sample/blank for ion filtering = 3
# [I 210804 12:40:11 IODA_MS2Planner_workflow:338]     Minimum intensity for ion filtering in sample = 0.00e+00
# [I 210804 12:40:11 IODA_MS2Planner_workflow:339]     Precursor ion intensity to accumulate in the MS2 scan = 4.00e+04
# [I 210804 12:40:11 IODA_MS2Planner_workflow:340]     Isolation window (m/z) = 1.5
# [I 210804 12:40:11 IODA_MS2Planner_workflow:341]     Delay between targeted MS2 scans (sec.)= 0.02
# [I 210804 12:40:11 IODA_MS2Planner_workflow:342]     Minimum MS2 scan duty cycle (sec.)= 0.1
# [I 210804 12:40:11 IODA_MS2Planner_workflow:343]     Maximum MS2 scan duty cycle (sec.)= 0.5
# [I 210804 12:40:11 IODA_MS2Planner_workflow:345]     Number of iterative experiment(s) = 3
# [I 210804 12:40:11 IODA_MS2Planner_workflow:346] User-defined parameters for the output
# [I 210804 12:40:11 IODA_MS2Planner_workflow:347]     Retention time margin for target ion list (sec. = 1
# [I 210804 12:40:11 IODA_MS2Planner_workflow:348]     Orbitrap transient + overhead time for MaxQuant.Live (msec.) = 80
# [I 210804 12:40:11 IODA_MS2Planner_workflow:350] ======
# [I 210804 12:40:11 IODA_MS2Planner_workflow:353] Running MS2Planner in Apex mode ...
# [I 210804 12:40:11 IODA_MS2Planner_workflow:694] Command: python3 MS2Planner/path_finder.py apex results_targeted_MS2Planner_apex/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.csv results_targeted_MS2Planner_apex/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd_MS2Planner.csv 0 3 3 -intensity_accu 40000.0 -isolation 1.5 -delay 0.02 -min_scan 0.1 -max_scan 0.5
# [I 210804 12:40:13 IODA_MS2Planner_workflow:370] ======
# [I 210804 12:40:13 IODA_MS2Planner_workflow:374] 2021-08-04 12:40:13,174 - path_finder - INFO - =============
#     2021-08-04 12:40:13,175 - path_finder - INFO - Apex mode begin
#     2021-08-04 12:40:13,175 - path_finder - INFO - =============
#     2021-08-04 12:40:13,175 - path_finder - INFO - File Read
#     2021-08-04 12:40:13,175 - path_finder - INFO - =============
#     2021-08-04 12:40:13,175 - path_finder - INFO - Begin Finding Path
#     2021-08-04 12:40:13,175 - path_finder - INFO - =============
#     2021-08-04 12:40:13,243 - path_finder.apex - INFO - [1/3]: features: 721, rest: 2734
#     2021-08-04 12:40:13,270 - path_finder.apex - INFO - [2/3]: features: 456, rest: 2013
#     2021-08-04 12:40:13,290 - path_finder.apex - INFO - [3/3]: features: 304, rest: 1557
#     2021-08-04 12:40:13,292 - path_finder - INFO - Paths Generated
#     2021-08-04 12:40:13,292 - path_finder - INFO - =============
#     2021-08-04 12:40:13,308 - path_finder - INFO - File Written
#     2021-08-04 12:40:13,308 - path_finder - INFO - =============
#
# [I 210804 12:40:13 IODA_MS2Planner_workflow:376] ======
# [I 210804 12:40:13 IODA_MS2Planner_workflow:381] MS2Planner output found
# [I 210804 12:40:13 IODA_MS2Planner_workflow:391] Preparing results ...
# [I 210804 12:40:13 IODA_MS2Planner_workflow:651] File processed: results_targeted_MS2Planner_apex/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd_MS2Planner.csv
# [I 210804 12:40:13 IODA_MS2Planner_workflow:652] ======
# [I 210804 12:40:13 IODA_MS2Planner_workflow:644] Valid target ions in path1 = 721
# [I 210804 12:40:13 IODA_MS2Planner_workflow:661] Formatting to XCalibur format ...
# [I 210804 12:40:13 IODA_MS2Planner_workflow:664] Formatting for MaxQuant.Live ...
# [I 210804 12:40:14 IODA_MS2Planner_workflow:667] =======
# [I 210804 12:40:14 IODA_MS2Planner_workflow:644] Valid target ions in path2 = 456
# [I 210804 12:40:14 IODA_MS2Planner_workflow:661] Formatting to XCalibur format ...
# [I 210804 12:40:14 IODA_MS2Planner_workflow:664] Formatting for MaxQuant.Live ...
# [I 210804 12:40:14 IODA_MS2Planner_workflow:667] =======
# [I 210804 12:40:14 IODA_MS2Planner_workflow:644] Valid target ions in path3 = 304
# [I 210804 12:40:14 IODA_MS2Planner_workflow:661] Formatting to XCalibur format ...
# [I 210804 12:40:14 IODA_MS2Planner_workflow:664] Formatting for MaxQuant.Live ...
# [I 210804 12:40:14 IODA_MS2Planner_workflow:667] =======
# [I 210804 12:40:14 IODA_MS2Planner_workflow:676] results_targeted_MS2Planner_apex
# [I 210804 12:40:18 IODA_MS2Planner_workflow:393] ======
# [I 210804 12:40:18 IODA_MS2Planner_workflow:395] Cleaning and zipping workflow results files ...
# [I 210804 12:40:18 IODA_MS2Planner_workflow:119] All files zipped successfully!
# [I 210804 12:40:18 IODA_MS2Planner_workflow:424] ======
# [I 210804 12:40:18 IODA_MS2Planner_workflow:425] END OF THE MS2Planner WORKFLOW
# [I 210804 12:40:18 IODA_MS2Planner_workflow:426] ======

# %%
from IPython.display import Image
Image("results_targeted_MS2Planner_apex/plots/injection_scatter_plot_intensity_rt.png")

# %%
Image("results_targeted_MS2Planner_apex/plots/injection_scatter_plot_mz_rt.png")

# %%
Image("results_targeted_MS2Planner_apex/plots/scatter_plot_duration.png")

# %% [markdown]
# ### MS2Planner in Curve mode

# %% [raw]
# MS2Planner_Curve_OpenMS(input_SAMPLE)

# %%
# Curve parameters
rt_tolerance_curve = 2 
mz_tolerance_curve = 0.02
intensity_accu = 1e6
curve = 'kNN'

# %%
# Run Path Finder with Curve method
from IODA_MS2Planner_workflow import *

#run_MS2Planner_curve_from_mzTab('OpenMS_generated', experiment_number, min_ratio_value, min_intensity_value, 'OpenMS_generated', intensity_accu, rt_tolerance_curve, mz_tolerance_curve, isolation, delay, min_scan, max_scan, curve, rt_margin, transient_time)
#run_MS2Planner_curve_from_mzTab('OpenMS_generated', experiment_number, min_ratio_value, min_intensity_value, input_SAMPLE, intensity_accu, rt_tolerance_curve, mz_tolerance_curve, isolation, delay, min_scan, max_scan, curve, rt_margin, transient_time)

# %%
# !python3 MS2Planner/path_finder.py curve results_targeted_MS2Planner_curve/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.csv results_targeted_MS2Planner_curve/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd_MS2Planner.csv 0 3 3 -infile_raw tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_latex_MS1_2uL.mzML -intensity_accu 1000000.0 -restriction 2 0.02 -isolation 1.5 -delay 0.02 -min_scan 0.1 -max_scan 0.5 -cluster kNN
# Out:
# PathGen
# CentroidSampleControl
# kNNCluster
# kNN
# NodesCreate
# ClusterCreate
# EdgeCreate
# EdgeCreate for i in clusters
# EdgeCreate for i in range(len(clusters))
# EdgeCreate return edges
# AddPrimeNode
# AddPrimeNode for i in range(num_edge)
# AddPrimeNode for i in range(num_edge)
# PathExtraction
# IndexHis
# ClusterRemove
# EdgeCreate
# EdgeCreate for i in clusters
# EdgeCreate for i in range(len(clusters))
# Killed

# %%
from IPython.display import Image
Image("results_targeted_MS2Planner_curve/plots/injection_scatter_plot_intensity_rt.png")

# %%
Image("results_targeted_MS2Planner_curve/plots/injection_scatter_plot_mz_rt.png")

# %%
Image("results_targeted_MS2Planner_curve/plots/scatter_plot_duration.png")
