# %% [markdown]
# # <span style="color:red"> MS2Planner notebook for IODA </span>
#
# **Purpose**: The IODA MSPlanner workflow runs MS2Planner for iterative optimise data acquisition (IODA) of fragmentation spectra in LC-MS. It accepts as input *EITHER*:
#  1) A pair of `mzML` or `RAW` files ("blank" sample, "reference" sample) [EASIEST]. It will be used for feature detection and alignement with pyOpenMS to generate an mzTab that will be used for MS2Planner.
#  2) A `mzTab` file or an `MZmine feature table` along with a `mzML` file for the sample (Curve mode).
#
# The targets are retrived from the "reference" sample, and background ions are detected in the "blank" sample. Background ions are excluded from the targets. The targets can be acquired by IODA in one or multiple experiments for higher coverage with for XCalibur or [MaxQuant.Live](http://www.maxquant.live/).
#
# **Documentation**: Please refer to the documentation page [See here NOT YET AVAILABLE](link).
#
# **Instructions**: Follow the instructions below and run the notebook cells accordingly.
#
# <!--These are various test jobs
# from importlib import reload
# import IODA_MS2Planner_workflow
# reload(IODA_MS2Planner_workflow)
# from IODA_MS2Planner_workflow import *
#
#
# #input_file = 'tests/Euphorbia/Targeted/ioda_input/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.mzTab'
# #input_file = 'tests/MZmine3/Targeted/MZmine_3_test_quant.csv'
# #input_file = 'tests/BP_mzTab/SA113_Media_SPE_MeOH_MS1_to_SA113_SPE_MeOH_MS1_mrgd.mzTab'
# -->

# %% [markdown]
# ### Step 0 - Run your LC-MS mass spectrometry experiments
#
# Analyse your "reference" and "blank" samples by LC-MS.
#
# <span style="color:brown">**IMPORTANT**</span>: The chromatographic and mass spectrometry conditions must be identical for all the samples analyzed with IODA. Make sure the chromatographic system was well equilibrated and is stable. Note that there is no need for MS/MS acquisition for the reference and blank, as feature detection/alignment with pyOpenMS is performed only on the MS1 level. The following IODA-targeted experiments requires MS/MS acquisition.
#
# ### Step 1 - Upload the files to the workspace
#
# Upload your mzML/RAW files on the Binder server with the Jupyter lab interface (drag-and-drop the file in the left panel or use the "Upload" icon).
#
# #### Step 2 - Load the functions by running the cell below

# %%
import sys
sys.path.append('src')
from IPython.display import Image
import glob
from IODA_MS2Planner_workflow import *
from IODA_run_pyOpenMS_targeted import *

# %% [markdown]
# ## A) Starting from a pair of mzML/RAW files
#
# Upload your mzML files to the workspace and specify the path to use for the blank and reference samples.

# %%
input_BLANK = "tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_Blank_MS1_2uL.mzML"
input_SAMPLE = "tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_latex_MS1_2uL.mzML"

# %% [markdown]
# ### Set the variables for the pyOpenMS feature detection and alignement
#
# **Specify the variables of the pyOpenMS processing**
#
# Parameters should be optimised depending on the sample complexity and acquisition parameters. You can visualize the data of your mzML file with OpenMS/TOPPView to decide upon the best noise level, see the [documentation](documentation.ipynb).
#
# The OpenMS workflow uses the Feature Finder Metabolomics (FFM) tool to detect LC-MS features/peaks. The parameters below are for the FFM tool. The minimum peak height for detected feature is set to 3 fold the noise level set.
#
# ##### Maximum mass error
# > `ppm_error`: the maximum mass error allowed for the feature detection. A value of 10 ppm is recommended for a resolution of 35K or less (must be an integer/float).
#
# ##### Noise level
# > `noise_level`: this is the MS1 noise level for the detection of narrow LC-MS features. The default value is 1E5 (must be an integer/float, can be in scientific format).
#
# TIPS: If your sample has a lot of features, increase the noise levels to limit the number of ions that are detected for subsequent exclusion.

# %%
ppm_error = 3
noise_level = 1E6
chrom_peak_snr = 3
elements_alphabet = 'CHNOPS'

# %%
IODA_targeted_workflow(input_BLANK, input_SAMPLE, ppm_error,noise_level, chrom_peak_snr, elements_alphabet)
input_file = glob.glob('OpenMS_workflow/OpenMS_output/*MS2Planner.csv')[0]
input_file_curve = input_SAMPLE
# Out:
# rm: cannot remove 'OpenMS_workflow/logfile_IODA_OpenMS_from_mzML.txt': No such file or directory
# rm: cannot remove 'download_results/IODA_OpenMS_results.zip': No such file or directory
# [I 230329 19:09:42 IODA_run_pyOpenMS_targeted:46] 2023-03-29 19:09:42.251866
# [I 230329 19:09:42 IODA_run_pyOpenMS_targeted:47] STARTING the IODA-targeted WORKFLOW
# [I 230329 19:09:42 IODA_run_pyOpenMS_targeted:48] ======
# [I 230329 19:09:42 IODA_run_pyOpenMS_targeted:49] Path to the input files:
# [I 230329 19:09:42 IODA_run_pyOpenMS_targeted:50] Blank: tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_Blank_MS1_2uL.mzML
# [I 230329 19:09:42 IODA_run_pyOpenMS_targeted:51] Sample: tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_latex_MS1_2uL.mzML
# [I 230329 19:09:42 IODA_run_pyOpenMS_targeted:133] Copying the mzML files ...
# [I 230329 19:09:42 IODA_run_pyOpenMS_targeted:63] 2023-03-29 19:09:42.267377
# [I 230329 19:09:42 IODA_run_pyOpenMS_targeted:64] STARTING the IODA-targeted WORKFLOW with OpenMS
# [I 230329 19:09:42 IODA_run_pyOpenMS_targeted:65] ======
# [I 230329 19:09:42 IODA_run_pyOpenMS_targeted:66] Getting the mzML, please wait ...
# [I 230329 19:09:42 IODA_run_pyOpenMS_targeted:105] This is the input file path: tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_Blank_MS1_2uL.mzML
# [I 230329 19:09:42 IODA_run_pyOpenMS_targeted:128] The mzML file was found !
# [I 230329 19:09:42 IODA_run_pyOpenMS_targeted:130] Copying the mzML to the OpenMS input folder
# [I 230329 19:09:42 IODA_run_pyOpenMS_targeted:63] 2023-03-29 19:09:42.385273
# [I 230329 19:09:42 IODA_run_pyOpenMS_targeted:64] STARTING the IODA-targeted WORKFLOW with OpenMS
# [I 230329 19:09:42 IODA_run_pyOpenMS_targeted:65] ======
# [I 230329 19:09:42 IODA_run_pyOpenMS_targeted:66] Getting the mzML, please wait ...
# [I 230329 19:09:42 IODA_run_pyOpenMS_targeted:105] This is the input file path: tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_latex_MS1_2uL.mzML
# [I 230329 19:09:42 IODA_run_pyOpenMS_targeted:128] The mzML file was found !
# [I 230329 19:09:42 IODA_run_pyOpenMS_targeted:130] Copying the mzML to the OpenMS input folder
# Mass Trace Detection:  OpenMS_workflow/OpenMS_input/Euphorbia_rogers_latex_Blank_MS1_2uL.mzML
# Elution Peak Detection:  OpenMS_workflow/OpenMS_input/Euphorbia_rogers_latex_Blank_MS1_2uL.mzML
# Progress of 'mass trace detection':
# -- done [took 1.00 s (CPU), 1.00 s (Wall)] --
# Warning: ElutionPeakDetection received the unknown parameter 'enabled'!
# Progress of 'elution peak detection':
# -- done [took 0.12 s (CPU), 0.08 s (Wall)] --
# Feature Detection:  OpenMS_workflow/OpenMS_input/Euphorbia_rogers_latex_Blank_MS1_2uL.mzML
# Progress of 'assembling mass traces to features':
# Mass Trace Detection:  OpenMS_workflow/OpenMS_input/Euphorbia_rogers_latex_latex_MS1_2uL.mzML
# -- done [took 0.03 s (CPU), 0.08 s (Wall)] --
# Progress of 'mass trace detection':Elution Peak Detection:  OpenMS_workflow/OpenMS_input/Euphorbia_rogers_latex_latex_MS1_2uL.mzML
# Feature Detection:  OpenMS_workflow/OpenMS_input/Euphorbia_rogers_latex_latex_MS1_2uL.mzML
#
# -- done [took 2.37 s (CPU), 2.39 s (Wall)] --
# Progress of 'elution peak detection':
# -- done [took 1.82 s (CPU), 1.79 s (Wall)] --
# Progress of 'assembling mass traces to features':
# -- done [took 0.07 s (CPU), 0.06 s (Wall)] --
# Finished Feature Detection
# [I 230329 19:09:55 IODA_run_pyOpenMS_targeted:338] ======
# [I 230329 19:09:55 IODA_run_pyOpenMS_targeted:339] Completed the OpenMS workflow
# [I 230329 19:09:55 IODA_run_pyOpenMS_targeted:340] ======
# [I 230329 19:09:55 IODA_run_pyOpenMS_targeted:341] Zipping up the OpenMS workflow results ..
# Progress of 'computing RT transformations':
# -- done [took 0.02 s (CPU), 0.01 s (Wall)] --
# Progress of 'linking features':
# -- done [took 0.02 s (CPU), 0.03 s (Wall)] --
# [I 230329 19:09:55 IODA_exclusion_workflow:159] All files zipped successfully!
# [I 230329 19:09:55 IODA_run_pyOpenMS_targeted:344] ======
# [I 230329 19:09:55 IODA_run_pyOpenMS_targeted:345] Completed zipping up the OpenMS workflow result files
# [I 230329 19:09:55 IODA_run_pyOpenMS_targeted:347] ======
# [I 230329 19:09:55 IODA_run_pyOpenMS_targeted:348] NOW CONTINUE WITH THE REST OF THE IODA-targeted WORKFLOW

# %% [markdown]
# ## B) Starting from an mzTab or a MZmine3 feature table
# If you ran the cell above, you can just ignore that one.
#
# Otherwise, upload either an `mzTab` file or the `MZmine feature table` along with the `mzML`/`RAW` file for the reference sample to the workspace and specify the paths to use:

# %%
input_file = 'tests/Euphorbia/Targeted/ioda_input/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.mzTab'
input_file_curve = 'tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_latex_MS1_2uL.mzML'

#input_file = 'tests/BP_mzTab/SA113_Media_SPE_MeOH_MS1_to_SA113_SPE_MeOH_MS1_mrgd.mzTab'
#input_file_curve = 'tests/BP_mzTab/SA113_Media_SPE_MeOH_MS1.mzML'

#input_file = 'tests/MZmine3/Targeted/MZmine_3_test_quant.csv'
#input_file_curve = ''

# %% [markdown]
# ## Prepare MS2Planner parameters

# %%
# Feature table filtering parameters (pre-MS2Planner step) 
max_same_RT = 3 #default 3

# MS2Planner shared parameters
min_ratio_value = 10
min_intensity_value = 5E6 # 1E5
experiment_number = 15
isolation = 1
delay = 0.01 #sec
transient_time = 30 #ms
 
# Parameters only considered to generate the final target list
rt_margin = 0.12 #sec
apex_int_percent = 0.6          # For Exploris serie, ratio of the apex to be defined as MS2 trigger intensity - only for 'int' output tables.
polarity = 'Positive'           # 'Positive' or 'Negative'
pretarget_rt_margin = 0.1       # Decrease the rt_start for the target by this value (secs)
posttarget_rt_margin = 0.1      # Increase the rt_end for the target by this value (secs)
RF_base_value = 70              # Optional
CEs = 35                        # Optional

# %% [markdown]
# # Baseline mode
#
# ### Prepare Baseline mode parameters

# %%
# MS2Planner - Baseline parameter
win_len = 0.2   #seconds
#max_same_RT = 5 #default 3

# %% [markdown]
# ### Run MS2Planner in Baseline mode

# %%
# Run Path Finder with Baseline method 
MS2Planner_baseline(
    input_file, experiment_number, min_ratio_value, min_intensity_value, 
    win_len, isolation, delay, rt_margin, 
    max_same_RT, transient_time,
    polarity, apex_int_percent = apex_int_percent,
    pretarget_rt_margin = pretarget_rt_margin, posttarget_rt_margin = posttarget_rt_margin
                    )
# Out:
# [I 230329 19:17:21 IODA_MS2Planner_workflow:322] STARTING THE MS2Planner WORKFLOW
# [I 230329 19:17:21 IODA_MS2Planner_workflow:330] File path to a mzTab was specified by the user
# [I 230329 19:17:21 IODA_MS2Planner_workflow:342] 2023-03-29 19:17:21.729280
# [I 230329 19:17:21 IODA_MS2Planner_workflow:344] ======
# [I 230329 19:17:21 IODA_MS2Planner_workflow:345] Getting the mzTab
# [I 230329 19:17:21 IODA_MS2Planner_workflow:367] This is the input file path: tests/Euphorbia/Targeted/ioda_input/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.mzTab
# [I 230329 19:17:21 IODA_MS2Planner_workflow:368] This is the output file path: results_targeted_MS2Planner_baseline/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd.csv
# [I 230329 19:17:21 IODA_MS2Planner_workflow:372] ======
# [I 230329 19:17:21 IODA_MS2Planner_workflow:373] Converting to intermediate table format ...
# [I 230329 19:17:21 IODA_MS2Planner_workflow:75] - For sample Euphorbia_rogers_latex_Blank_MS1_2uL the sum of feature intensities is = 6.67e+08
# [I 230329 19:17:21 IODA_MS2Planner_workflow:77] - For sample Euphorbia_rogers_latex_latex_MS1_2uL the sum of feature intensities = 5.75e+10
# [I 230329 19:17:21 IODA_MS2Planner_workflow:375] ======
# [I 230329 19:17:21 IODA_MS2Planner_workflow:380] Assumed sample filename: Euphorbia_rogers_latex_latex_MS1_2uL
# [I 230329 19:17:21 IODA_MS2Planner_workflow:382] Assumed blank filename: Euphorbia_rogers_latex_Blank_MS1_2uL
# [I 230329 19:17:21 IODA_MS2Planner_workflow:383] ======
# [I 230329 19:17:21 IODA_MS2Planner_workflow:386] = PARAMETERS ==
# [I 230329 19:17:21 IODA_MS2Planner_workflow:387]
# [I 230329 19:17:21 IODA_MS2Planner_workflow:388] == MS2Planner parameters
# [I 230329 19:17:21 IODA_MS2Planner_workflow:390]     Ratio between sample/blank for ion filtering = 10
# [I 230329 19:17:21 IODA_MS2Planner_workflow:392]     Minimum intensity for ion filtering in sample = 5.00e+06
# [I 230329 19:17:21 IODA_MS2Planner_workflow:393]     Retention time window (secs) for binning target ions = 0.2
# [I 230329 19:17:21 IODA_MS2Planner_workflow:394]     Isolation window (m/z) = 1
# [I 230329 19:17:21 IODA_MS2Planner_workflow:395]     Transient time (ms) = 30
# [I 230329 19:17:21 IODA_MS2Planner_workflow:396]     Retention time margin (sec.) = 0.01
# [I 230329 19:17:21 IODA_MS2Planner_workflow:398]     Number of iterative experiment(s) = 15
# [I 230329 19:17:21 IODA_MS2Planner_workflow:399]
# [I 230329 19:17:21 IODA_MS2Planner_workflow:400] == Output target list parameters
# Input file is an mzTab
# [I 230329 19:17:21 IODA_MS2Planner_workflow:401]     Polarity = Positive
# [I 230329 19:17:21 IODA_MS2Planner_workflow:402]     Exactive serie retention time window for target ion list (sec. = 0.24)
# [I 230329 19:17:21 IODA_MS2Planner_workflow:403]     MQL retention time window for target ion list = apex - 0.12 secs)
# [I 230329 19:17:21 IODA_MS2Planner_workflow:404]     Exploris: Pretarget retention time margin for target ion list (sec. = 0.1)
# [I 230329 19:17:21 IODA_MS2Planner_workflow:405]     Exploris: Posttarget retention time margin for target ion list (sec. = 0.1)
# [I 230329 19:17:21 IODA_MS2Planner_workflow:406]     Exploris serie RF base value = nan
# [I 230329 19:17:21 IODA_MS2Planner_workflow:407]     Exploris serie CEs = nan
# [I 230329 19:17:21 IODA_MS2Planner_workflow:409]
# [I 230329 19:17:21 IODA_MS2Planner_workflow:410] == Pre-filtering input table ===
# [I 230329 19:17:21 IODA_MS2Planner_workflow:411]    Number of features in the table = 6026
# [I 230329 19:17:21 IODA_MS2Planner_workflow:413]    Remaining features = 910 after the intensity/ratio filtering
# [I 230329 19:17:21 IODA_MS2Planner_workflow:232]    Remaining features = 775 after same RT filtering with top 3
# [I 230329 19:17:21 IODA_MS2Planner_workflow:415]
# [I 230329 19:17:21 IODA_MS2Planner_workflow:418] Running MS2Planner in Baseline mode ...
# [I 230329 19:17:21 IODA_MS2Planner_workflow:962] Command: python3 MS2Planner_lfnothias/path_finder.py baseline results_targeted_MS2Planner_baseline/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd_filtered.csv results_targeted_MS2Planner_baseline/Euphorbia_rogers_latex_Blank_MS1_2uL_to_Euphorbia_rogers_latex_latex_MS1_2uL_mrgd_filtered_MS2Planner_baseline.csv 5000000.0 10 15 -win_len 0.2 -isolation 1 -delay 0.01 -max_same_RT 3
# [I 230329 19:17:23 IODA_MS2Planner_workflow:435] ======
# [I 230329 19:17:23 IODA_MS2Planner_workflow:439] 2023-03-29 19:17:23,256 - MS2Planner - INFO - =============
#     2023-03-29 19:17:23,256 - MS2Planner - INFO - Baseline mode begin
#     2023-03-29 19:17:23,256 - MS2Planner - INFO - =============
#     2023-03-29 19:17:23,256 - MS2Planner - INFO - File Read
#     2023-03-29 19:17:23,256 - MS2Planner - INFO - =============
#     2023-03-29 19:17:23,259 - MS2Planner.baseline - INFO -    Initial number of features = 775
#     2023-03-29 19:17:23,263 - MS2Planner.baseline - INFO -    Remaining features = 775 after same RT filtering with top 3
#     2023-03-29 19:17:23,263 - MS2Planner - INFO - Begin Finding Path
#     2023-03-29 19:17:23,263 - MS2Planner - INFO - =============
#     2023-03-29 19:17:23,286 - MS2Planner.baseline - INFO - Total number of features: 776
#     2023-03-29 19:17:23,287 - MS2Planner.baseline - INFO - Maximum number of iterative experiments: 15
#     2023-03-29 19:17:23,287 - MS2Planner.baseline - INFO - [1/15 max]: features: 460, rest: 316
#     2023-03-29 19:17:23,287 - MS2Planner.baseline - INFO - [2/15 max]: features: 176, rest: 140
#     2023-03-29 19:17:23,287 - MS2Planner.baseline - INFO - [3/15 max]: features: 96, rest: 44
#     2023-03-29 19:17:23,287 - MS2Planner.baseline - INFO - [4/15 max]: features: 29, rest: 15
#     2023-03-29 19:17:23,287 - MS2Planner.baseline - INFO - [5/15 max]: features: 10, rest: 5
#     2023-03-29 19:17:23,287 - MS2Planner.baseline - INFO - [6/15 max]: features: 5, rest: 0
#     2023-03-29 19:17:23,287 - MS2Planner - INFO - Paths Generated
#     2023-03-29 19:17:23,287 - MS2Planner - INFO - =============
#     2023-03-29 19:17:23,287 - MS2Planner - INFO - Running WriteFile
#     2023-03-29 19:17:23,294 - MS2Planner - INFO - File Written
#     2023-03-29 19:17:23,295 - MS2Planner - INFO - =============
#
# [I 230329 19:17:23 IODA_MS2Planner_workflow:445] MS2Planner Path output found
# [I 230329 19:17:23 IODA_MS2Planner_workflow:454] Preparing results ...
# [I 230329 19:17:39 IODA_MS2Planner_workflow:497] ======
# [I 230329 19:17:39 IODA_MS2Planner_workflow:268] Cleaning and zipping workflow results files ...
# [I 230329 19:17:39 IODA_MS2Planner_workflow:223] All files zipped successfully!
# [I 230329 19:17:39 IODA_MS2Planner_workflow:300] ======
# [I 230329 19:17:39 IODA_MS2Planner_workflow:301] END OF THE MS2Planner WORKFLOW - baseline mode
# [I 230329 19:17:39 IODA_MS2Planner_workflow:302] ======

# %% [markdown]
# ### Visualization - **Baseline mode results**
#
# ### Examine the results
#
# **Visualise** : Run the cell below to show the scatter plot for the IODA-targeted workflow results. Valid targets in the reference sample are represented into experiment(s). The ion/features from the blank sample are also shown. Verify that the feature detection parameter variables and IODA-targeted workflows are adapted to level you want to apply, and your sample(s) complexity.
#
# - Examine the IODA-targeted worflow log and the plots in order to verify that the 'min_intensity' parameter is adapted to exclusion level you want to apply, and your sample(s) complexity.
# - Note that, at this stage, it cannot be evaluated if ion detection was done optimally. This should be examinated during the generation of the feature table or the mzTab file (such as with TOPPAS/OpenMS).

# %%
#### RT | m/z
filename = glob.glob('results_targeted_MS2Planner_baseline/plots/*_ALL_plot_mz_rt.png')
Image(filename[0])

# %%
#### RT | int
filename = glob.glob('results_targeted_MS2Planner_baseline/plots/*_ALL_plot_rt_int.png')
Image(filename[0])

# %%
#### m/z | RT
filename = glob.glob('results_targeted_MS2Planner_baseline/plots/*_ALL_plot_mz_int.png')
Image(filename[0])

# %% [markdown]
# # MS2Planner in Apex mode
#
# ### Prepare Apex mode parameters

# %%
# MS2Planner - Shared between Apex and Curve modes
intensity_accumulated = 8e3
min_scan = 0.1
max_scan = 0.2

# %% [markdown]
# ### Run MS2Planner in Apex mode
#
# This is pretty quick ...

# %%
MS2Planner_apex(
    input_file, experiment_number, min_ratio_value, min_intensity_value, 
    intensity_accumulated, isolation, delay, min_scan, max_scan,
    rt_margin, max_same_RT, transient_time,
    polarity,apex_int_percent,pretarget_rt_margin, posttarget_rt_margin)

# %% [markdown]
# ### Visualization - **Apex mode results**
#
# ### Examine the results
#
# **Visualise** : Run the cell below to show the scatter plot for the IODA-targeted workflow results. Valid targets in the reference sample are represented into experiment(s). The ion/features from the blank sample are also shown. Verify that the feature detection parameter variables and IODA-targeted workflows are adapted to level you want to apply, and your sample(s) complexity.
#
# - Examine the IODA-targeted worflow log and the plots in order to verify that the 'min_intensity' parameter is adapted to exclusion level you want to apply, and your sample(s) complexity.
# - Note that, at this stage, it cannot be evaluated if ion detection was done optimally. This should be examinated during the generation of the feature table or the mzTab file (such as with TOPPAS/OpenMS).

# %%
#### RT | m/z
filename = glob.glob('results_targeted_MS2Planner_apex/plots/*_ALL_plot_mz_rt.png')
Image(filename[0])

# %%
#### RT | int
filename = glob.glob('results_targeted_MS2Planner_apex/plots/*_ALL_plot_rt_int.png')
Image(filename[0])

# %%
#### m/z | RT
filename = glob.glob('results_targeted_MS2Planner_apex/plots/*_ALL_plot_mz_int.png')
Image(filename[0])

# %% [markdown]
# ### Download the results
#
# Download the IODA-targeted workflow results ->
# [download_results_targeted_MS2Planner_apex/IODA_MS2Planner_curve_apex.zip](download_results_targeted_MS2Planner_apex/IODA_MS2Planner_curve_apex.zip?download=1).
#
# ### Prepare your IODA experiment
# Prepare the iterative mass spectrometry acquisition. For instructions on how to load and configure an exclusion list with XCalibur or MaxQuant.Live please refer to [the following documentation](nothing).

# %% [markdown]
# # MS2Planner in Curve mode
#
# This mode should be the most the perfomant.
#
# ### Prepare Curve mode parameters

# %%
#CURVE MODE PARAMETERS
rt_tolerance_curve = 3 #secs
mz_tolerance_curve = 5 #m/z
restriction = 2
cluster = 'kNN'
max_same_RT = 5

# %% [markdown]
# ### Run MS2Planner in Curve mode
#
# This can take several minutes. The amount of RAM can reach 10-16 GB depending on the number of features and mass spec data.

# %%
MS2Planner_curve(input_file, experiment_number, min_ratio_value,
                    min_intensity_value, input_file_curve, 
                    intensity_accumulated, 
                    rt_tolerance_curve, mz_tolerance_curve, 
                    isolation, delay, min_scan, max_scan, cluster, 
                    rt_margin, transient_time, max_same_RT, 
                    apex_int_percent, polarity, 
                    pretarget_rt_margin, posttarget_rt_margin
                    #RF_base_value=70, CEs=['20,35,50']
                    )
# Out:
# [I 230329 16:44:55 IODA_MS2Planner_workflow:721] STARTING THE MS2Planner WORKFLOW
# [I 230329 16:44:55 IODA_MS2Planner_workflow:726] File path to a MZmine3 feature table was specified by the user
# [I 230329 16:44:55 IODA_MS2Planner_workflow:741] 2023-03-29 16:44:55.090664
# [I 230329 16:44:55 IODA_MS2Planner_workflow:743] ======
# [I 230329 16:44:55 IODA_MS2Planner_workflow:744] Getting the mzTab
# [I 230329 16:44:55 IODA_MS2Planner_workflow:761] This is the input file path: OpenMS_workflow/OpenMS_output/consensus_MS2Planner.csv
# [I 230329 16:44:55 IODA_MS2Planner_workflow:762] This is the output file path: results_targeted_MS2Planner_curve/consensus_MS2Planner.csv
# [I 230329 16:44:55 IODA_MS2Planner_workflow:771] ======
# [I 230329 16:44:55 IODA_MS2Planner_workflow:772] Converting to intermediate table format ...
# [I 230329 16:44:55 IODA_MS2Planner_workflow:122] - For sample Euphorbia_rogers_latex_Blank_MS1_2uL.mzML, the sum of feature intensities = 5.34e+08
# [I 230329 16:44:55 IODA_MS2Planner_workflow:123] - For sample Euphorbia_rogers_latex_latex_MS1_2uL.mzML, the sum of feature intensities = 3.89e+10
# [I 230329 16:44:55 IODA_MS2Planner_workflow:124] - The blank sample is assumed to be Euphorbia_rogers_latex_Blank_MS1_2uL.mzML in the feature table
# [I 230329 16:44:55 IODA_MS2Planner_workflow:125] - The sample is assumed to be Euphorbia_rogers_latex_latex_MS1_2uL.mzML in the feature table
# [I 230329 16:44:55 IODA_MS2Planner_workflow:774] ======
# [I 230329 16:44:55 IODA_MS2Planner_workflow:779] Assumed sample filename: Euphorbia_rogers_latex_latex_MS1_2uL.mzML
# [I 230329 16:44:55 IODA_MS2Planner_workflow:781] Assumed blank filename: Euphorbia_rogers_latex_Blank_MS1_2uL.mzML
# [I 230329 16:44:55 IODA_MS2Planner_workflow:782] ======
# [I 230329 16:44:55 IODA_MS2Planner_workflow:785] = PARAMETERS ==
# [I 230329 16:44:55 IODA_MS2Planner_workflow:786]
# [I 230329 16:44:55 IODA_MS2Planner_workflow:787] == MS2Planner parameters
# [I 230329 16:44:55 IODA_MS2Planner_workflow:789]     Ratio between sample/blank for ion filtering = 10
# [I 230329 16:44:55 IODA_MS2Planner_workflow:791]     Minimum intensity for ion filtering in sample = 5.00e+06
# [I 230329 16:44:55 IODA_MS2Planner_workflow:792]     Precursor ion intensity to accumulate in the MS2 scan = 8.00e+03
# [I 230329 16:44:55 IODA_MS2Planner_workflow:793]     Input file for curve data : tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_latex_MS1_2uL.mzML
# [I 230329 16:44:55 IODA_MS2Planner_workflow:794]     Restriction parameter : 3
# [I 230329 16:44:55 IODA_MS2Planner_workflow:795]     Mass accuracy (m/z): 5
# [I 230329 16:44:55 IODA_MS2Planner_workflow:796]     Isolation window (m/z) = 1
# [I 230329 16:44:55 IODA_MS2Planner_workflow:797]     Delay between targeted MS2 scans (sec.)= 0.01
# [I 230329 16:44:55 IODA_MS2Planner_workflow:798]     Transient time (msec.) = 30
# [I 230329 16:44:55 IODA_MS2Planner_workflow:799]     Retention time margin (sec.) = 0.01
# [I 230329 16:44:55 IODA_MS2Planner_workflow:800]     Minimum MS2 scan duty cycle (sec.)= 0.1
# [I 230329 16:44:55 IODA_MS2Planner_workflow:801]     Maximum MS2 scan duty cycle (sec.)= 0.2
# [I 230329 16:44:55 IODA_MS2Planner_workflow:803]     Number of iterative experiment(s) = 15
# [I 230329 16:44:55 IODA_MS2Planner_workflow:804]     Mode for the curve mode: kNN
# [I 230329 16:44:55 IODA_MS2Planner_workflow:805]
# [I 230329 16:44:55 IODA_MS2Planner_workflow:806] == Output target list parameters
# [I 230329 16:44:55 IODA_MS2Planner_workflow:807]     Polarity = Positive
# [I 230329 16:44:55 IODA_MS2Planner_workflow:808]     Orbitrap transient + overhead time for MaxQuant.Live (msec.) = 30
# [I 230329 16:44:55 IODA_MS2Planner_workflow:809]     Exactive serie retention time window for target ion list (sec. = 0.24)
# [I 230329 16:44:55 IODA_MS2Planner_workflow:810]     MQL retention time window for target ion list = apex - 0.12 secs)
# [I 230329 16:44:55 IODA_MS2Planner_workflow:811]     Exploris: Pretarget retention time margin for target ion list (sec. = 0.1)
# [I 230329 16:44:55 IODA_MS2Planner_workflow:812]     Exploris: Posttarget retention time margin for target ion list (sec. = 0.1)
# [I 230329 16:44:55 IODA_MS2Planner_workflow:813]     Exploris serie RF base value = nan
# [I 230329 16:44:55 IODA_MS2Planner_workflow:814]     Exploris serie CEs = nan
# [I 230329 16:44:55 IODA_MS2Planner_workflow:815]
# [I 230329 16:44:55 IODA_MS2Planner_workflow:816] === FILTERING THE INPUT FEATURE TABLE ===
# [I 230329 16:44:55 IODA_MS2Planner_workflow:817]    Number of features in the table = 1970
# [I 230329 16:44:55 IODA_MS2Planner_workflow:819]    Remaining features = 742 after the intensity/ratio filtering
# [I 230329 16:44:55 IODA_MS2Planner_workflow:232]    Remaining features = 686 after same RT filtering with top 5
# [I 230329 16:44:55 IODA_MS2Planner_workflow:821]
# [I 230329 16:44:55 IODA_MS2Planner_workflow:824] Running MS2Planner in Curve mode ...
# [I 230329 16:44:55 IODA_MS2Planner_workflow:972] Command: python3 MS2Planner_lfnothias/path_finder.py curve results_targeted_MS2Planner_curve/consensus_MS2Planner_filtered.csv results_targeted_MS2Planner_curve/consensus_MS2Planner_filtered_MS2Planner.csv 5000000.0 10 15 -infile_raw tests/Euphorbia/Targeted/toppas_input/Euphorbia_rogers_latex_latex_MS1_2uL.mzML -intensity_accu 8000.0 -restriction 3 5 -isolation 1 -delay 0.01 -min_scan 0.1 -max_scan 0.2 -cluster kNN -max_same_RT 5
# [I 230329 16:44:55 IODA_MS2Planner_workflow:973] MS2Planner in Curve mode can take up to 10 minutes to complete ... please wait
# [I 230329 16:44:55 IODA_MS2Planner_workflow:974] Output of MS2Planner: results_targeted_MS2Planner_curve/consensus_MS2Planner_filtered_MS2Planner.csv
# Input file is a consensus table from pyOpenMS
# Number of features before filter: 687
# Number of features after same_max_RT filter: 687
# Start GenPath for each path
# ====== New path processed
# EdgeCreate
# AddPrimeNode
# addEdge
# Killed
# [I 230329 16:45:43 IODA_MS2Planner_workflow:845] ======
# [I 230329 16:45:43 IODA_MS2Planner_workflow:849] 2023-03-29 16:44:56,427 - MS2Planner - INFO - =============
#     2023-03-29 16:44:56,428 - MS2Planner - INFO - Curve mode begin
#     2023-03-29 16:44:56,428 - MS2Planner - INFO - restriction: (3.0000, 5.0000)
#     2023-03-29 16:45:04,967 - MS2Planner.curve - INFO - =============
#     2023-03-29 16:45:04,967 - MS2Planner.curve - INFO - File Read
#     2023-03-29 16:45:04,967 - MS2Planner.curve - INFO - =============
#     2023-03-29 16:45:21,262 - MS2Planner.curve - INFO - Begin Finding Path
#     2023-03-29 16:45:21,262 - MS2Planner.curve - INFO - =============
#
# [I 230329 16:45:43 IODA_MS2Planner_workflow:859] Problem when running MS2Planner !!!
# [I 230329 16:45:43 IODA_MS2Planner_workflow:863] ======
# [I 230329 16:45:43 IODA_MS2Planner_workflow:864] Preparing results ...
# <---------- !!!!!!!!!!!!!!!!!! ---------->
# Problem when running MS2Planner !!!
# <---------- !!!!!!!!!!!!!!!!!! ---------->
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 MS2Planner_curve(input_file, experiment_number, min_ratio_value,
#       2                     min_intensity_value, input_file_curve,
#       3                     intensity_accumulated,
#       4                     rt_tolerance_curve, mz_tolerance_curve,
#       5                     isolation, delay, min_scan, max_scan, cluster,
#       6                     rt_margin, transient_time, max_same_RT,
#       7                     apex_int_percent, polarity,
#       8                     pretarget_rt_margin, posttarget_rt_margin
#       9                     #RF_base_value=70, CEs=['20,35,50']
#      10                     )
#
# File ~/src/IODA_MS2Planner_workflow.py:902, in MS2Planner_curve(input_filename, num_path, intensity_ratio, intensity_threshold, input_filename_curve, intensity_accu, rt_tolerance_curve, mz_tolerance_curve, isolation, delay, min_scan, max_scan, cluster, rt_margin, transient_time, max_same_RT, apex_int_percent, polarity, pretarget_rt_margin, posttarget_rt_margin, RF_base_value, CEs)
#     894 for i in range(count):
#     895     generate_Exploris_tMS2_table_from_MS2Planner(
#     896         output_filename[:-4]+'_filtered_MS2Planner_curve_path_'+str(i+1)+'.csv',
#     897         output_filename[:-4]+'_filtered_MS2Planner_curve_path_'+str(i+1)+'_Exploris_tMS2.txt',
#     898         pretarget_rt_margin=pretarget_rt_margin,  posttarget_rt_margin=posttarget_rt_margin,
#     899         transient_time=transient_time, polarity=polarity,
#     900         RF_base_value=RF_base_value, CEs=CEs)
# --> 902 make_plot_MS2Planner(output_filename,directory,count, 'curve')
#     904 generate_outputs(output_dir, 'curve')
#
# File ~/src/IODA_MS2Planner_workflow.py:260, in make_plot_MS2Planner(output_filename, directory, count, mode)
#     255     table_list_MS2Planner.append(
#     256         output_filename[:-4]+'_filtered_MS2Planner_'+mode+'_path_'+str(x+1)+'.csv')
#     258 try:
#     259     # print(table_list_MS2Planner)
# --> 260     make_plot_MS2Planner_RT_mz(table_list_MS2Planner, directory)
#     261     make_plot_MS2Planner_mz_int(table_list_MS2Planner, directory)
#     262     make_plot_MS2Planner_RT_int(table_list_MS2Planner, directory)
#
# File ~/src/IODA_MS2Planner_workflow.py:1011, in make_plot_MS2Planner_RT_mz(table_list_MS2Planner, output_dir)
#    1007     plt.title('Distribution of MS2Planner targets. Node size shows intensity with a scale factor of '+str(scaling_factor), fontsize=8)
#    1008     plt.savefig(table_path[:-4]+'_plot_mz_rt.png', dpi=300)
# -> 1011 plt.savefig(table_list_MS2Planner[0][:-6]+'_ALL_plot_mz_rt.png', dpi=300)
#    1012 plt.close()
#
# IndexError: list index out of range

# %% [markdown]
# ### Visualization - **Curve mode results**
#
# ### Examine the results
#
# **Visualise** : Run the cell below to show the scatter plot for the IODA-targeted workflow results. Valid targets in the reference sample are represented into experiment(s). The ion/features from the blank sample are also shown. Verify that the feature detection parameter variables and IODA-targeted workflows are adapted to level you want to apply, and your sample(s) complexity.
#
# - Examine the IODA-targeted worflow log and the plots in order to verify that the 'min_intensity' parameter is adapted to exclusion level you want to apply, and your sample(s) complexity.
# - Note that, at this stage, it cannot be evaluated if ion detection was done optimally. This should be examinated during the generation of the feature table or the mzTab file (such as with TOPPAS/OpenMS).

# %%
#### RT | m/z
filename = glob.glob('results_targeted_MS2Planner_curve/plots/*_ALL_plot_mz_rt.png')
Image(filename[0])

# %%
#### RT | int
filename = glob.glob('results_targeted_MS2Planner_curve/plots/*_ALL_plot_rt_int.png')
Image(filename[0])

# %%
#### m/z | RT
filename = glob.glob('results_targeted_MS2Planner_curve/plots/*_ALL_plot_mz_int.png')
Image(filename[0])

# %% [markdown]
# ### Download the results
#
# Download the IODA-targeted workflow results ->
# [download_results_targeted_MS2Planner_curve/IODA_MS2Planner_curve_results.zip](download_results_targeted_MS2Planner_curve/IODA_MS2Planner_curve_results.zip.zip?download=1).
#
# ### Prepare your IODA experiment
# Prepare the iterative mass spectrometry acquisition. For instructions on how to load and configure an exclusion list with XCalibur or MaxQuant.Live please refer to [the following documentation](nothing).

# %% [markdown]
# ### Step 0 - Generate an mzTab file
#
# The mzTab file must contain results from feature detection and alignment for the two samples: the "reference" sample and the "blank' sample. Please refer to the [documentation page](link) for more information.
#
# ### Step 1 - Upload the mzTab file
#
# ##### <span style="color:brown">Method 1 - Upload your mzTab file </span>
#
# Upload your mzML files on the Binder server with the Jupyter lab interface (drag-and-drop the file in the left panel or use the "Upload" icon).
#
# ##### <span style="color:brown">Method 2 - Web-sharing links</span>
# We support retrieving the files from the following cloud sharing services:
# > **Google Drive** : copy the sharing the link (make sure the sharing setting is set to 'Anyone with the link can download').
#
# > **MassIVE/GNPS repository** : copy the link for the file.
#
#
# ### Step 3 - Specify the link or path to the mzTab file
#
# In the cell below, indicate the filename for the mzTab file. The filename must be into parenthesis,  such as: *"myfile.mzTab"*. If applicable change the path, such *"input_folder/myfile.mzTab"*.

# %%
input_mzTab = 'https://drive.google.com/file/d/1NGVzhrw-xZ4nMJserIQ7v4tYgcmraZ6g/view?usp=sharing'

# %% [markdown]
# ### Step 4 - Specify the parameters of the IODA-targeted workflow
# Specify the parameter values for IODA-targeted workflow in the cell below:
#
# *min_ratio_value*: minimum ratio for the intensity of an ion/feature (peak height) between the reference and blank samples (reference/blank). Only ions above that ratio will be valid ion targets. (Default = 5).
#
# *min_intensity_value*: the minimum intensity (peak height) of an ion/feature in the reference sample to be considered as valid ion targets. (Default = 1E5).
#
# *experiment_number*: define the number of iterative experiment(s) to perform for the IODA-targeted workflow. If >2, the valid target ions will be splitted into (multiple) experiments (Default = 3, range 1-10)

# %%
min_ratio_value = 5
min_intensity_value = 1E5
experiment_number = 3

# %% [markdown]
# ### Step 5 - Run the IODA-targeted workflow
#
# Simply run the cell below to start the IODA-targeted workflow

# %%
from IODA_targeted_workflow import *
make_targeted_list_from_mzTab(input_mzTab, experiment_number, min_ratio_value, min_intensity_value)

# %% [markdown]
# ### Step 6 - Examine the results
#
# **Visualise** : Run the cell below to show the scatter plot for the IODA-targeted workflow results. Valid targets in the reference sample are represented into experiment(s). The ion/features from the blank sample are also shown. Verify that the OpenMS parameter variables and IODA-targeted workflows are adapted to level you want to apply, and your sample(s) complexity.
#
# - Examine the IODA-targeted worflow log and the plots in order to verify that the 'min_intensity' parameter is adapted to exclusion level you want to apply, and your sample(s) complexity.
# - Note that, at this stage, it cannot be evaluated if ion detection was done optimally. This should be examinated during the generation of the mzTab file (such as with TOPPAS/OpenMS).

# %%
from IPython.display import Image
Image("results_targeted/intermediate_files/experiment_blank_shared_TARGETED_RATIO_scatter_view.png")
Image("results_targeted/intermediate_files/experiment_blank_shared_TARGETED_INTENSITY_scatter_view.png")
